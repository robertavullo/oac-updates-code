# %% [markdown]
# ## Welcome to the new and improved deleted DOIs error trends analysis process
# ### Simply add your login code below between the quotation marks, then click *Cell* > *Run All*

# %%
login = "rvq5988"

# %%
from deleted_dois_error_trends_functions import create_error_trends
a, b, c = create_error_trends(login)
# Out:
# Reading the ORL...
# ... and this week's deleted DOIs...
# Formatting date columns...
# Formatting date columns...
# DOI deletion rate graph created!
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Old vs. New DOI verification status graph created!
# Reason for deletion pie chart created!
# Deletions by Journal analysis done!
# Analysis of deleted DOIs error trends split by PE done!
# Formatting the Excel file for the error trend team update email
# Deleted DOI error trend analysis completed in 0 minutes 22 seconds
# Done!
# Now send the update email to the team with screenshots of the saved images and of the tables below.

# %%
a
# Out:
# New verification status  Approved  Ineligible for Compact  No new DOI  \
# Old verification status
# Approved                     86.0                    39.0        56.0
# Not verified                 12.0                     4.0         1.0
# Opt-Out                      21.0                     6.0        13.0
# Rejected                     79.0                     8.0        19.0
#
# New verification status  Opt-Out  Rejected  \
# Old verification status
# Approved                    17.0       4.0
# Not verified                 2.0       1.0
# Opt-Out                      4.0       2.0
# Rejected                     6.0       5.0
#
# New verification status  Waiting for Author to Complete OASiS  Not verified
# Old verification status
# Approved                                                  8.0           0.0
# Not verified                                              0.0           0.0
# Opt-Out                                                   0.0           0.0
# ...

# %%
b
# Out:
# Reason for Deletion – Category  AM verified by mistake  \
# Agreement
# DEAL                                                18
# CARE                                                 4
# JISC                                                 3
# CSAL                                                 2
# Bibsam                                               2
# QNL                                                  1
# CDL                                                  0
# KEMÖ                                                 2
# UKB                                                  4
# Unit                                                 1
# HAS                                                  0
# FinELib                                              0
# ICM                                                  1
# CRUE-CSIC                                            2
#
# Reason for Deletion – Category  Author mistake in OA request forms  \
# Agreement
# ...

# %%
c
# Out:
# Reason for Deletion – Category                    AM verified by mistake  \
# Journal Title
# Allergo Journal International                                          0
# European Radiology                                                     0
# Journal of Mathematical Biology                                        0
# SN Computer Science                                                    0
# AI & SOCIETY                                                           0
# Journal of Neurology                                                   0
# Obere Extremität                                                       0
# Annali di Matematica Pura ed Applicata (1923 -)                        0
# BHM Berg- und Hüttenmännische Monatshefte                              0
# Der Nervenarzt                                                         1
# European Journal of Applied Physiology                                 1
# Journal of Business Ethics                                             0
# ...
